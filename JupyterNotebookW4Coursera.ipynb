# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bold Santiago Perdomo Mezzera**
# Data Scientist

# %% [markdown]
# *Im interested in Data Science because Im passionate about programming and statistics, as well as I want to create machine learning solutions for a better future.*

# %% [markdown]
# ### Run a simple mathematic problem

# %%
print(8+5*4)
# Out:
# 28

# %% [markdown]
# 1. Inspiration
# 1. Motivation
# 1. Discipline
# 1. Constant
#
# ![download.jpg](attachment:9cc86a75-031c-407d-b124-5cae9bde84bc.jpg)
#
# ***My horizontal line example***
